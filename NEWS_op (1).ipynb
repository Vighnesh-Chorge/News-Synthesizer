# %%
# !pip install feedparser newspaper3k transformers torch lxml[html_clean] tqdm
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.53.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: lxml[html_clean] in /usr/local/lib/python3.11/dist-packages (5.4.0)
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (4.13.4)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (11.2.1)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (6.0.2)
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading cssselect-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (3.9.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (2.32.3)
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading tldextract-5.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 63.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (2.9.0.post0)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.33.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Collecting lxml_html_clean (from lxml[html_clean])
#   Downloading lxml_html_clean-0.4.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.7)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.17.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2.1->newspaper3k) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2.1->newspaper3k) (1.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.10.0->newspaper3k) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.10.0->newspaper3k) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.10.0->newspaper3k) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.10.0->newspaper3k) (2025.7.14)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 8.0 MB/s eta 0:00:00
# Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 17.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 77.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 61.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 33.5 MB/s eta 0:00:00
# Downloading cssselect-1.3.0-py3-none-any.whl (18 kB)
# Downloading tldextract-5.3.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 8.8 MB/s eta 0:00:00
# Downloading lxml_html_clean-0.4.2-py3-none-any.whl (14 kB)
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13540 sha256=b57bf8d03ba8a1a6122299a64cf9ef2ab0bae63de80edc8c2b011b6d4a5df32c
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/f8/cce3a9ae6d828bd346be695f7ff54612cd22b7cbd7208d68f3
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3341 sha256=490cc9815e97b333a1055069148a5bcceb3ccccdb77d9190f44726cf86dc6215
#   Stored in directory: /root/.cache/pip/wheels/80/d5/72/9cd9eccc819636436c6a6e59c22a0fb1ec167beef141f56491
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398380 sha256=aa5d14a553e4f990d744a9d12bfb259312207446e70beae079fca79505d37846
#   Stored in directory: /root/.cache/pip/wheels/3a/a1/46/8e68055c1713f9c4598774c15ad0541f26d5425ee7423b6493
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=294c509e7a9135fc0e092a11cefce720e0686edc4645be5c3ff1a82d2d635a4e
#   Stored in directory: /root/.cache/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lxml_html_clean, feedparser, cssselect, requests-file, nvidia-cusparse-cu12, nvidia-cudnn-cu12, feedfinder2, tldextract, nvidia-cusolver-cu12, newspaper3k
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed cssselect-1.3.0 feedfinder2-0.0.4 feedparser-6.0.11 jieba3k-0.35.1 lxml_html_clean-0.4.2 newspaper3k-0.2.8 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 requests-file-2.1.0 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-5.3.0

# %%
import feedparser
from newspaper import Article
from transformers import pipeline
from sentence_transformers import SentenceTransformer, util
import torch
import time
import json
from tqdm import tqdm
import os

# 2. Define RSS feeds
RSS_FEEDS = {
    "Times of India": "https://timesofindia.indiatimes.com/rssfeeds/-2128936835.cms",
    "The Hindu": "https://www.thehindu.com/feeder/default.rss",
    "Indian Express": "https://indianexpress.com/feed",
    "BBC News": "http://feeds.bbci.co.uk/news/rss.xml",
    "Reuters": "https://www.reutersagency.com/feed/?best-topics=top-news",
    "NDTV": "https://feeds.feedburner.com/ndtvnews-top-stories",
    "Al Jazeera": "https://www.aljazeera.com/xml/rss/all.xml",
    "The Guardian": "https://www.theguardian.com/world/rss",
    "Times Now": "https://www.timesnownews.com/rssfeedstopstories.cms",
    "Deccan Herald": "https://www.deccanherald.com/rss-feeds/top-stories"
}

# 3. Load models
device = 0 if torch.cuda.is_available() else -1
summarizer = pipeline("summarization", model="facebook/bart-large-cnn", device=device)
embedder = SentenceTransformer('all-MiniLM-L6-v2')

# ML Classifier (transformer-based)
news_classifier = pipeline(
    "text-classification",
    model="classla/multilingual-IPTC-news-topic-classifier",
    device=device
)


# 🧠 Keyword-based news classification
def classify_article(text):
    try:
        text = text.strip()[:512]  # limit for tokenizer safety
        pred = news_classifier(text)
        label = pred[0]["label"]

        # Fallback to keyword-based rules if the ML label is fuzzy
        if label.lower() in ["other", "miscellaneous", "uncategorized"]:
            return classify_article_keywords(text)
        return label
    except:
        return classify_article_keywords(text)


# 4. Collect articles
articles = []
for source, feed_url in tqdm(RSS_FEEDS.items(), desc="Processing feeds"):
    try:
        feed = feedparser.parse(feed_url)
        for entry in feed.entries[:200]:  # Adjust number per source as needed
            title = entry.get('title', '')
            link = entry.get('link', '')
            published = entry.get('published', '') or entry.get('pubDate', '')
            try:
                article = Article(link)
                article.download()
                article.parse()
                full_text = article.text
                if not full_text or len(full_text) < 200:
                    continue
            except Exception:
                continue
            articles.append({
                "source": source,
                "title": title,
                "url": link,
                "published": published,
                "full_text": full_text
            })
            time.sleep(0.5)
    except Exception as e:
        print(f"Error processing {source}: {e}")
print(f"Collected {len(articles)} articles.")

# 5. Group articles by event/topic using semantic similarity
titles = [a['title'] for a in articles]
embeddings = embedder.encode(titles, convert_to_tensor=True)
clusters = []
used = set()
threshold = 0.7  # Similarity threshold; adjust as needed

for i, emb in enumerate(embeddings):
    if i in used:
        continue
    cluster = [i]
    for j in range(i+1, len(embeddings)):
        if j in used:
            continue
        sim = util.pytorch_cos_sim(emb, embeddings[j]).item()
        if sim > threshold:
            cluster.append(j)
            used.add(j)
    used.add(i)
    clusters.append(cluster)
print(f"Grouped into {len(clusters)} events/topics.")

# 6. For each event/topic, synthesize summary and full article
results = []
for cluster in tqdm(clusters, desc="Synthesizing events"):
    topic_articles = [articles[i] for i in cluster]
    combined_text = "\n\n".join([a['full_text'] for a in topic_articles])
    combined_titles = " | ".join([a['title'] for a in topic_articles])
    try:
        # Truncate to max input length for BART (1024 tokens ≈ 2000 chars)
        safe_text = combined_text[:2000]
        summary = summarizer(safe_text, max_length=150, min_length=50, do_sample=False)[0]['summary_text']
        synthesized_article = summarizer(safe_text, max_length=512, min_length=200, do_sample=False)[0]['summary_text']
    except Exception:
        summary = combined_text[:500]
        synthesized_article = combined_text[:2000]
    results.append({
        "event_titles": combined_titles,
        "sources": [a['source'] for a in topic_articles],
        "urls": [a['url'] for a in topic_articles],
        "category": classify_article(combined_titles + " " + summary + " " + synthesized_article),
        "summary": summary,
        "synthesized_article": synthesized_article
    })
print(f"✅ Synthesized {len(results)} multi-source event summaries.")
from google.colab import drive
drive.mount('/content/drive')

# Define output path
output_path = "/content/drive/MyDrive/New News/multi_source_event_synthesis.json"

# Delete old file if it exists
if os.path.exists(output_path):
    os.remove(output_path)
    print("🗑️ Previous JSON file deleted.")

# Save new JSON
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(results, f, ensure_ascii=False, indent=2)
print(f"✅ JSON saved to Google Drive ➜ New News folder.")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cuda:0
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# Device set to use cuda:0
# Processing feeds: 100%|██████████| 10/10 [05:41<00:00, 34.19s/it]
# Collected 436 articles.
# Grouped into 386 events/topics.
# Synthesizing events:   0%|          | 0/386 [00:00<?, ?it/s]Your max_length is set to 512, but your input_length is only 422. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=211)
# Synthesizing events:   0%|          | 1/386 [00:05<37:11,  5.80s/it]Your max_length is set to 512, but your input_length is only 429. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=214)
# Synthesizing events:   1%|          | 2/386 [00:10<34:44,  5.43s/it]Your max_length is set to 512, but your input_length is only 315. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=157)
# Synthesizing events:   1%|          | 3/386 [00:15<31:58,  5.01s/it]Your max_length is set to 512, but your input_length is only 439. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=219)
# Synthesizing events:   1%|          | 4/386 [00:20<31:46,  4.99s/it]Your max_length is set to 512, but your input_length is only 458. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=229)
# Synthesizing events:   1%|▏         | 5/386 [00:25<31:20,  4.94s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Your max_length is set to 512, but your input_length is only 286. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=143)
# Synthesizing events:   2%|▏         | 6/386 [00:29<29:47,  4.70s/it]Your max_length is set to 512, but your input_length is only 468. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=234)
# Synthesizing events:   2%|▏         | 7/386 [00:34<30:55,  4.90s/it]Your max_length is set to 512, but your input_length is only 427. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=213)
# Synthesizing events:   2%|▏         | 8/386 [00:39<31:02,  4.93s/it]Your max_length is set to 512, but your input_length is only 431. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=215)
# Synthesizing events:   2%|▏         | 9/386 [00:44<30:43,  4.89s/it]Your max_length is set to 512, but your input_length is only 185. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=92)
# Synthesizing events:   3%|▎         | 10/386 [00:49<30:46,  4.91s/it]Your max_length is set to 512, but your input_length is only 420. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=210)
# Synthesizing events:   3%|▎         | 11/386 [00:54<30:04,  4.81s/it]Your max_length is set to 512, but your input_length is only 376. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=188)
# Synthesizing events:   3%|▎         | 12/386 [00:58<29:42,  4.77s/it]Your max_length is set to 512, but your input_length is only 434. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=217)
# Synthesizing events:   3%|▎         | 13/386 [01:04<31:37,  5.09s/it]Your max_length is set to 512, but your input_length is only 203. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=101)
# Synthesizing events:   4%|▎         | 14/386 [01:08<29:56,  4.83s/it]Your max_length is set to 512, but your input_length is only 405. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=202)
# Synthesizing events:   4%|▍         | 15/386 [01:14<30:42,  4.97s/it]Your max_length is set to 512, but your input_length is only 444. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=222)
# Synthesizing events:   4%|▍         | 16/386 [01:19<31:17,  5.07s/it]Your max_length is set to 512, but your input_length is only 237. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=118)
# Synthesizing events:   4%|▍         | 17/386 [01:23<29:35,  4.81s/it]Your max_length is set to 512, but your input_length is only 429. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=214)
# Synthesizing events:   5%|▍         | 18/386 [01:29<31:02,  5.06s/it]Your max_length is set to 512, but your input_length is only 409. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=204)
# Synthesizing events:   5%|▍         | 19/386 [01:34<30:13,  4.94s/it]Your max_length is set to 512, but your input_length is only 400. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=200)
# Synthesizing events:   5%|▌         | 20/386 [01:38<29:50,  4.89s/it]Your max_length is set to 512, but your input_length is only 462. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=231)
# Synthesizing events:   5%|▌         | 21/386 [01:44<30:59,  5.09s/it]Your max_length is set to 512, but your input_length is only 181. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=90)
# Synthesizing events:   6%|▌         | 22/386 [01:48<29:22,  4.84s/it]Your max_length is set to 512, but your input_length is only 435. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=217)
# Synthesizing events:   6%|▌         | 23/386 [01:53<29:16,  4.84s/it]Your max_length is set to 512, but your input_length is only 229. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=114)
# Synthesizing events:   6%|▌         | 24/386 [01:58<29:37,  4.91s/it]Your max_length is set to 512, but your input_length is only 467. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=233)
# Synthesizing events:   6%|▋         | 25/386 [02:03<28:54,  4.81s/it]Your max_length is set to 512, but your input_length is only 426. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=213)
# Synthesizing events:   7%|▋         | 26/386 [02:08<30:10,  5.03s/it]Your max_length is set to 512, but your input_length is only 346. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=173)
# Synthesizing events:   7%|▋         | 27/386 [02:13<29:44,  4.97s/it]Your max_length is set to 512, but your input_length is only 290. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=145)
# Synthesizing events:   8%|▊         | 29/386 [02:24<30:57,  5.20s/it]Your max_length is set to 512, but your input_length is only 510. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=255)
# Synthesizing events:   8%|▊         | 30/386 [02:28<30:08,  5.08s/it]Your max_length is set to 512, but your input_length is only 440. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=220)
# Synthesizing events:   8%|▊         | 31/386 [02:33<29:25,  4.97s/it]Your max_length is set to 512, but your input_length is only 245. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=122)
# Synthesizing events:   8%|▊         | 32/386 [02:38<29:43,  5.04s/it]Your max_length is set to 512, but your input_length is only 469. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=234)
# Synthesizing events:   9%|▊         | 33/386 [02:43<29:34,  5.03s/it]Your max_length is set to 512, but your input_length is only 496. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=248)
# Synthesizing events:   9%|▉         | 34/386 [02:49<31:21,  5.34s/it]Your max_length is set to 512, but your input_length is only 414. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=207)
# Synthesizing events:   9%|▉         | 35/386 [02:54<30:07,  5.15s/it]Your max_length is set to 512, but your input_length is only 494. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=247)
# Synthesizing events:   9%|▉         | 36/386 [02:59<29:47,  5.11s/it]Your max_length is set to 512, but your input_length is only 507. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=253)
# Synthesizing events:  10%|▉         | 37/386 [03:06<32:05,  5.52s/it]Your max_length is set to 512, but your input_length is only 461. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=230)
# Synthesizing events:  10%|▉         | 38/386 [03:10<30:31,  5.26s/it]Your max_length is set to 512, but your input_length is only 152. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=76)
# Synthesizing events:  10%|█         | 39/386 [03:16<30:31,  5.28s/it]Your max_length is set to 512, but your input_length is only 312. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=156)
# Synthesizing events:  10%|█         | 40/386 [03:20<29:33,  5.13s/it]Your max_length is set to 512, but your input_length is only 416. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=208)
# Synthesizing events:  11%|█         | 41/386 [03:25<28:32,  4.96s/it]Your max_length is set to 512, but your input_length is only 349. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=174)
# Synthesizing events:  11%|█         | 42/386 [03:31<29:29,  5.14s/it]Your max_length is set to 512, but your input_length is only 300. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=150)
# Synthesizing events:  11%|█         | 43/386 [03:35<27:56,  4.89s/it]Your max_length is set to 512, but your input_length is only 422. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=211)
# Synthesizing events:  11%|█▏        | 44/386 [03:40<28:11,  4.95s/it]Your max_length is set to 512, but your input_length is only 399. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=199)
# Synthesizing events:  12%|█▏        | 45/386 [03:45<28:52,  5.08s/it]Your max_length is set to 512, but your input_length is only 441. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=220)
# Synthesizing events:  12%|█▏        | 46/386 [03:50<27:58,  4.94s/it]Your max_length is set to 512, but your input_length is only 440. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=220)
# Synthesizing events:  12%|█▏        | 48/386 [04:00<28:18,  5.03s/it]Your max_length is set to 512, but your input_length is only 407. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=203)
# Synthesizing events:  13%|█▎        | 49/386 [04:05<28:40,  5.10s/it]Your max_length is set to 512, but your input_length is only 196. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=98)
# Synthesizing events:  13%|█▎        | 50/386 [04:11<29:02,  5.19s/it]Your max_length is set to 512, but your input_length is only 382. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=191)
# Synthesizing events:  13%|█▎        | 51/386 [04:15<27:58,  5.01s/it]Your max_length is set to 512, but your input_length is only 434. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=217)
# Synthesizing events:  14%|█▎        | 53/386 [04:27<29:24,  5.30s/it]Your max_length is set to 512, but your input_length is only 233. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=116)
# Synthesizing events:  14%|█▍        | 54/386 [04:31<27:51,  5.04s/it]Your max_length is set to 512, but your input_length is only 206. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=103)
# Synthesizing events:  14%|█▍        | 55/386 [04:36<28:17,  5.13s/it]Your max_length is set to 512, but your input_length is only 261. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=130)
# Synthesizing events:  15%|█▍        | 56/386 [04:41<27:05,  4.93s/it]Your max_length is set to 512, but your input_length is only 450. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=225)
# Synthesizing events:  15%|█▍        | 57/386 [04:46<26:41,  4.87s/it]Your max_length is set to 512, but your input_length is only 421. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=210)
# Synthesizing events:  15%|█▌        | 58/386 [04:51<27:33,  5.04s/it]Your max_length is set to 150, but your input_length is only 97. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 512, but your input_length is only 97. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Synthesizing events:  15%|█▌        | 59/386 [04:55<26:05,  4.79s/it]Your max_length is set to 512, but your input_length is only 457. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=228)
# Synthesizing events:  16%|█▌        | 60/386 [05:00<26:24,  4.86s/it]Your max_length is set to 512, but your input_length is only 378. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=189)
# Synthesizing events:  16%|█▌        | 61/386 [05:05<26:45,  4.94s/it]Your max_length is set to 512, but your input_length is only 461. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=230)
# Synthesizing events:  16%|█▌        | 62/386 [05:10<26:30,  4.91s/it]Your max_length is set to 512, but your input_length is only 307. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=153)
# Synthesizing events:  16%|█▋        | 63/386 [05:15<26:49,  4.98s/it]Your max_length is set to 512, but your input_length is only 411. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=205)
# Synthesizing events:  17%|█▋        | 64/386 [05:20<26:45,  4.99s/it]Your max_length is set to 150, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 512, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Synthesizing events:  17%|█▋        | 65/386 [05:24<25:22,  4.74s/it]Your max_length is set to 512, but your input_length is only 467. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=233)
# Synthesizing events:  17%|█▋        | 66/386 [05:31<28:08,  5.28s/it]Your max_length is set to 512, but your input_length is only 448. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=224)
# Synthesizing events:  17%|█▋        | 67/386 [05:36<27:56,  5.26s/it]Your max_length is set to 512, but your input_length is only 433. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=216)
# Synthesizing events:  18%|█▊        | 68/386 [05:41<27:41,  5.22s/it]Your max_length is set to 512, but your input_length is only 431. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=215)
# Synthesizing events:  18%|█▊        | 69/386 [05:46<27:25,  5.19s/it]Your max_length is set to 512, but your input_length is only 456. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=228)
# Synthesizing events:  18%|█▊        | 70/386 [05:51<26:18,  5.00s/it]Your max_length is set to 512, but your input_length is only 262. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=131)
# Synthesizing events:  18%|█▊        | 71/386 [05:57<27:21,  5.21s/it]Your max_length is set to 512, but your input_length is only 150. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=75)
# Synthesizing events:  19%|█▊        | 72/386 [06:01<26:12,  5.01s/it]Your max_length is set to 512, but your input_length is only 411. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=205)
# Synthesizing events:  19%|█▉        | 73/386 [06:06<25:22,  4.87s/it]Your max_length is set to 512, but your input_length is only 457. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=228)
# Synthesizing events:  19%|█▉        | 74/386 [06:12<26:37,  5.12s/it]Your max_length is set to 512, but your input_length is only 390. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=195)
# Synthesizing events:  19%|█▉        | 75/386 [06:16<26:09,  5.05s/it]Your max_length is set to 512, but your input_length is only 460. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=230)
# Synthesizing events:  20%|█▉        | 76/386 [06:22<26:43,  5.17s/it]Your max_length is set to 512, but your input_length is only 426. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=213)
# Synthesizing events:  20%|█▉        | 77/386 [06:27<26:11,  5.09s/it]Your max_length is set to 512, but your input_length is only 356. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=178)
# Synthesizing events:  20%|██        | 78/386 [06:31<25:14,  4.92s/it]Your max_length is set to 512, but your input_length is only 354. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=177)
# Synthesizing events:  20%|██        | 79/386 [06:37<26:05,  5.10s/it]Your max_length is set to 512, but your input_length is only 483. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=241)
# Synthesizing events:  21%|██        | 80/386 [06:41<25:13,  4.95s/it]Your max_length is set to 512, but your input_length is only 432. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=216)
# Synthesizing events:  21%|██        | 81/386 [06:46<24:36,  4.84s/it]Your max_length is set to 512, but your input_length is only 373. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=186)
# Synthesizing events:  21%|██        | 82/386 [06:51<25:23,  5.01s/it]Your max_length is set to 512, but your input_length is only 298. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=149)
# Synthesizing events:  22%|██▏       | 83/386 [06:56<24:43,  4.90s/it]Your max_length is set to 512, but your input_length is only 362. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=181)
# Synthesizing events:  22%|██▏       | 84/386 [07:01<24:22,  4.84s/it]Your max_length is set to 512, but your input_length is only 265. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=132)
# Synthesizing events:  22%|██▏       | 85/386 [07:06<24:59,  4.98s/it]Your max_length is set to 512, but your input_length is only 437. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=218)
# Synthesizing events:  22%|██▏       | 86/386 [07:11<24:15,  4.85s/it]Your max_length is set to 512, but your input_length is only 488. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=244)
# Synthesizing events:  23%|██▎       | 87/386 [07:16<25:05,  5.04s/it]Your max_length is set to 150, but your input_length is only 133. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=66)
# Your max_length is set to 512, but your input_length is only 133. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=66)
# Synthesizing events:  23%|██▎       | 88/386 [07:21<24:40,  4.97s/it]Your max_length is set to 512, but your input_length is only 326. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=163)
# Synthesizing events:  23%|██▎       | 89/386 [07:25<23:50,  4.81s/it]Your max_length is set to 512, but your input_length is only 266. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=133)
# Synthesizing events:  23%|██▎       | 90/386 [07:31<24:28,  4.96s/it]Your max_length is set to 150, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 512, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Synthesizing events:  24%|██▎       | 91/386 [07:35<23:31,  4.79s/it]Your max_length is set to 512, but your input_length is only 155. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=77)
# Synthesizing events:  24%|██▍       | 92/386 [07:40<23:17,  4.75s/it]Your max_length is set to 512, but your input_length is only 459. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=229)
# Synthesizing events:  24%|██▍       | 93/386 [07:46<24:50,  5.09s/it]Your max_length is set to 512, but your input_length is only 405. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=202)
# Synthesizing events:  25%|██▍       | 95/386 [07:57<26:39,  5.50s/it]Your max_length is set to 150, but your input_length is only 112. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Your max_length is set to 512, but your input_length is only 112. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Synthesizing events:  25%|██▍       | 96/386 [08:01<25:04,  5.19s/it]Your max_length is set to 150, but your input_length is only 109. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 512, but your input_length is only 109. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Synthesizing events:  25%|██▌       | 97/386 [08:06<23:42,  4.92s/it]Your max_length is set to 512, but your input_length is only 156. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=78)
# Synthesizing events:  25%|██▌       | 98/386 [08:11<23:45,  4.95s/it]Your max_length is set to 512, but your input_length is only 357. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=178)
# Synthesizing events:  26%|██▌       | 99/386 [08:15<23:22,  4.89s/it]Your max_length is set to 512, but your input_length is only 198. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=99)
# Synthesizing events:  26%|██▌       | 100/386 [08:20<22:43,  4.77s/it]Your max_length is set to 512, but your input_length is only 357. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=178)
# Synthesizing events:  26%|██▌       | 101/386 [08:26<23:50,  5.02s/it]Your max_length is set to 512, but your input_length is only 384. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=192)
# Synthesizing events:  26%|██▋       | 102/386 [08:30<23:24,  4.94s/it]Your max_length is set to 512, but your input_length is only 206. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=103)
# Synthesizing events:  27%|██▋       | 103/386 [08:35<22:48,  4.83s/it]Your max_length is set to 512, but your input_length is only 472. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=236)
# Synthesizing events:  27%|██▋       | 104/386 [08:40<23:11,  4.93s/it]Your max_length is set to 512, but your input_length is only 402. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=201)
# Synthesizing events:  27%|██▋       | 105/386 [08:45<22:51,  4.88s/it]Your max_length is set to 512, but your input_length is only 474. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=237)
# Synthesizing events:  27%|██▋       | 106/386 [08:51<24:02,  5.15s/it]Your max_length is set to 512, but your input_length is only 389. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=194)
# Synthesizing events:  28%|██▊       | 107/386 [08:55<23:30,  5.05s/it]Your max_length is set to 512, but your input_length is only 303. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=151)
# Synthesizing events:  28%|██▊       | 108/386 [09:00<22:37,  4.88s/it]Your max_length is set to 512, but your input_length is only 320. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=160)
# Synthesizing events:  28%|██▊       | 109/386 [09:05<23:23,  5.07s/it]Your max_length is set to 512, but your input_length is only 414. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=207)
# Synthesizing events:  28%|██▊       | 110/386 [09:10<22:37,  4.92s/it]Your max_length is set to 512, but your input_length is only 403. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=201)
# Synthesizing events:  29%|██▉       | 111/386 [09:15<22:39,  4.94s/it]Your max_length is set to 512, but your input_length is only 414. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=207)
# Synthesizing events:  29%|██▉       | 112/386 [09:20<22:29,  4.92s/it]Your max_length is set to 150, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 512, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Synthesizing events:  29%|██▉       | 113/386 [09:24<21:40,  4.76s/it]Your max_length is set to 512, but your input_length is only 433. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=216)
# Synthesizing events:  30%|██▉       | 114/386 [09:30<22:15,  4.91s/it]Your max_length is set to 512, but your input_length is only 384. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=192)
# Synthesizing events:  30%|██▉       | 115/386 [09:34<22:01,  4.88s/it]Your max_length is set to 512, but your input_length is only 193. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=96)
# Synthesizing events:  30%|███       | 116/386 [09:39<20:58,  4.66s/it]Your max_length is set to 512, but your input_length is only 227. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=113)
# Synthesizing events:  30%|███       | 117/386 [09:44<21:42,  4.84s/it]Your max_length is set to 512, but your input_length is only 448. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=224)
# Synthesizing events:  31%|███       | 118/386 [09:49<21:57,  4.92s/it]Your max_length is set to 512, but your input_length is only 429. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=214)
# Synthesizing events:  31%|███       | 119/386 [09:54<21:41,  4.87s/it]Your max_length is set to 512, but your input_length is only 244. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=122)
# Synthesizing events:  31%|███       | 120/386 [09:59<22:13,  5.01s/it]Your max_length is set to 512, but your input_length is only 443. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=221)
# Synthesizing events:  31%|███▏      | 121/386 [10:04<21:31,  4.87s/it]Your max_length is set to 512, but your input_length is only 487. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=243)
# Synthesizing events:  32%|███▏      | 122/386 [10:08<21:22,  4.86s/it]Your max_length is set to 512, but your input_length is only 439. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=219)
# Synthesizing events:  32%|███▏      | 123/386 [10:13<21:41,  4.95s/it]Your max_length is set to 512, but your input_length is only 213. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=106)
# Synthesizing events:  32%|███▏      | 124/386 [10:18<20:56,  4.80s/it]Your max_length is set to 512, but your input_length is only 457. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=228)
# Synthesizing events:  32%|███▏      | 125/386 [10:24<22:37,  5.20s/it]Your max_length is set to 512, but your input_length is only 444. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=222)
# Synthesizing events:  33%|███▎      | 126/386 [10:29<22:18,  5.15s/it]Your max_length is set to 512, but your input_length is only 469. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=234)
# Synthesizing events:  33%|███▎      | 127/386 [10:34<22:07,  5.13s/it]Your max_length is set to 512, but your input_length is only 426. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=213)
# Synthesizing events:  33%|███▎      | 128/386 [10:39<22:16,  5.18s/it]Your max_length is set to 512, but your input_length is only 458. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=229)
# Synthesizing events:  33%|███▎      | 129/386 [10:44<21:34,  5.04s/it]Your max_length is set to 512, but your input_length is only 219. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=109)
# Synthesizing events:  34%|███▎      | 130/386 [10:49<21:09,  4.96s/it]Your max_length is set to 512, but your input_length is only 414. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=207)
# Synthesizing events:  34%|███▍      | 131/386 [10:54<21:03,  4.95s/it]Your max_length is set to 150, but your input_length is only 113. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Your max_length is set to 512, but your input_length is only 113. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Synthesizing events:  34%|███▍      | 133/386 [11:04<21:35,  5.12s/it]Your max_length is set to 512, but your input_length is only 264. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=132)
# Synthesizing events:  35%|███▍      | 135/386 [11:14<21:19,  5.10s/it]Your max_length is set to 512, but your input_length is only 468. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=234)
# Synthesizing events:  35%|███▌      | 137/386 [11:24<20:44,  5.00s/it]Your max_length is set to 512, but your input_length is only 235. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=117)
# Synthesizing events:  36%|███▌      | 138/386 [11:29<20:20,  4.92s/it]Your max_length is set to 512, but your input_length is only 248. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=124)
# Synthesizing events:  36%|███▌      | 139/386 [11:34<19:57,  4.85s/it]Your max_length is set to 512, but your input_length is only 426. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=213)
# Synthesizing events:  36%|███▋      | 140/386 [11:38<19:40,  4.80s/it]Your max_length is set to 150, but your input_length is only 96. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 512, but your input_length is only 96. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Synthesizing events:  37%|███▋      | 141/386 [11:44<20:14,  4.96s/it]Your max_length is set to 512, but your input_length is only 435. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=217)
# Synthesizing events:  37%|███▋      | 142/386 [11:49<20:26,  5.03s/it]Your max_length is set to 512, but your input_length is only 214. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=107)
# ...
# Synthesizing events:  88%|████████▊ | 341/386 [28:10<03:36,  4.82s/it]Your max_length is set to 512, but your input_length is only 410. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=205)
# Synthesizing events:  89%|████████▊ | 342/386 [28:16<03:38,  4.95s/it]Your max_length is set to 150, but your input_length is only 78. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 512, but your input_length is only 78. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Synthesizing events:  89%|████████▉ | 343/386 [28:20<03:21,  4.68s/it]Your max_length is set to 512, but your input_length is only 410. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=205)
# Synthesizing events:  89%|████████▉ | 344/386 [28:25<03:23,  4.85s/it]Your max_length is set to 512, but your input_length is only 454. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=227)
# Synthesizing events:  89%|████████▉ | 345/386 [28:29<03:16,  4.78s/it]Your max_length is set to 512, but your input_length is only 464. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=232)
# Synthesizing events:  90%|████████▉ | 346/386 [28:34<03:05,  4.65s/it]Your max_length is set to 150, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 512, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Synthesizing events:  90%|████████▉ | 347/386 [28:39<03:05,  4.76s/it]Your max_length is set to 150, but your input_length is only 74. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 512, but your input_length is only 74. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Synthesizing events:  90%|█████████ | 348/386 [28:43<02:54,  4.59s/it]Your max_length is set to 512, but your input_length is only 446. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=223)
# Synthesizing events:  90%|█████████ | 349/386 [28:48<02:52,  4.67s/it]Your max_length is set to 150, but your input_length is only 80. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 512, but your input_length is only 80. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Synthesizing events:  91%|█████████ | 350/386 [28:53<02:51,  4.75s/it]Your max_length is set to 512, but your input_length is only 352. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=176)
# Synthesizing events:  91%|█████████ | 351/386 [28:57<02:44,  4.70s/it]Your max_length is set to 512, but your input_length is only 428. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=214)
# Synthesizing events:  91%|█████████ | 352/386 [29:02<02:38,  4.67s/it]Your max_length is set to 512, but your input_length is only 400. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=200)
# Synthesizing events:  91%|█████████▏| 353/386 [29:07<02:41,  4.88s/it]Your max_length is set to 512, but your input_length is only 453. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=226)
# Synthesizing events:  92%|█████████▏| 354/386 [29:12<02:34,  4.82s/it]Your max_length is set to 512, but your input_length is only 441. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=220)
# Synthesizing events:  92%|█████████▏| 355/386 [29:17<02:29,  4.81s/it]Your max_length is set to 512, but your input_length is only 483. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=241)
# Synthesizing events:  92%|█████████▏| 356/386 [29:22<02:29,  4.98s/it]Your max_length is set to 512, but your input_length is only 404. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=202)
# Synthesizing events:  92%|█████████▏| 357/386 [29:27<02:20,  4.85s/it]Your max_length is set to 512, but your input_length is only 424. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=212)
# Synthesizing events:  93%|█████████▎| 358/386 [29:32<02:20,  5.00s/it]Your max_length is set to 512, but your input_length is only 426. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=213)
# Synthesizing events:  93%|█████████▎| 359/386 [29:37<02:11,  4.88s/it]Your max_length is set to 512, but your input_length is only 447. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=223)
# Synthesizing events:  93%|█████████▎| 360/386 [29:41<02:05,  4.81s/it]Your max_length is set to 512, but your input_length is only 417. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=208)
# Synthesizing events:  94%|█████████▎| 361/386 [29:47<02:04,  5.00s/it]Your max_length is set to 512, but your input_length is only 294. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=147)
# Synthesizing events:  94%|█████████▍| 362/386 [29:51<01:55,  4.83s/it]Your max_length is set to 512, but your input_length is only 417. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=208)
# Synthesizing events:  94%|█████████▍| 363/386 [29:57<01:56,  5.05s/it]Your max_length is set to 512, but your input_length is only 417. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=208)
# Synthesizing events:  94%|█████████▍| 364/386 [30:02<01:51,  5.05s/it]Your max_length is set to 512, but your input_length is only 426. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=213)
# Synthesizing events:  95%|█████████▍| 365/386 [30:07<01:46,  5.07s/it]Your max_length is set to 512, but your input_length is only 160. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=80)
# Synthesizing events:  95%|█████████▍| 366/386 [30:12<01:41,  5.07s/it]Your max_length is set to 512, but your input_length is only 473. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=236)
# Synthesizing events:  95%|█████████▌| 367/386 [30:17<01:33,  4.93s/it]Your max_length is set to 512, but your input_length is only 263. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=131)
# Synthesizing events:  95%|█████████▌| 368/386 [30:21<01:24,  4.72s/it]Your max_length is set to 512, but your input_length is only 436. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=218)
# Synthesizing events:  96%|█████████▌| 369/386 [30:27<01:25,  5.02s/it]Your max_length is set to 512, but your input_length is only 423. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=211)
# Synthesizing events:  96%|█████████▌| 370/386 [30:31<01:19,  4.94s/it]Your max_length is set to 512, but your input_length is only 469. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=234)
# Synthesizing events:  96%|█████████▌| 371/386 [30:36<01:14,  4.94s/it]Your max_length is set to 512, but your input_length is only 423. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=211)
# Synthesizing events:  96%|█████████▋| 372/386 [30:41<01:09,  5.00s/it]Your max_length is set to 512, but your input_length is only 426. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=213)
# Synthesizing events:  97%|█████████▋| 373/386 [30:46<01:03,  4.86s/it]Your max_length is set to 512, but your input_length is only 434. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=217)
# Synthesizing events:  97%|█████████▋| 374/386 [30:51<00:58,  4.88s/it]Your max_length is set to 512, but your input_length is only 428. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=214)
# Synthesizing events:  97%|█████████▋| 375/386 [30:56<00:53,  4.85s/it]Your max_length is set to 512, but your input_length is only 401. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=200)
# Synthesizing events:  97%|█████████▋| 376/386 [31:00<00:46,  4.68s/it]Your max_length is set to 512, but your input_length is only 210. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=105)
# Synthesizing events:  98%|█████████▊| 377/386 [31:05<00:42,  4.74s/it]Your max_length is set to 512, but your input_length is only 432. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=216)
# Synthesizing events:  98%|█████████▊| 378/386 [31:10<00:38,  4.77s/it]Your max_length is set to 512, but your input_length is only 422. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=211)
# Synthesizing events:  98%|█████████▊| 379/386 [31:14<00:32,  4.67s/it]Your max_length is set to 512, but your input_length is only 493. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=246)
# Synthesizing events:  98%|█████████▊| 380/386 [31:19<00:29,  4.88s/it]Your max_length is set to 512, but your input_length is only 414. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=207)
# Synthesizing events:  99%|█████████▊| 381/386 [31:24<00:23,  4.73s/it]Your max_length is set to 512, but your input_length is only 410. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=205)
# Synthesizing events:  99%|█████████▉| 382/386 [31:28<00:18,  4.68s/it]Your max_length is set to 512, but your input_length is only 442. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=221)
# Synthesizing events:  99%|█████████▉| 383/386 [31:34<00:15,  5.01s/it]Your max_length is set to 512, but your input_length is only 458. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=229)
# Synthesizing events:  99%|█████████▉| 384/386 [31:39<00:09,  4.97s/it]Your max_length is set to 512, but your input_length is only 319. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=159)
# Synthesizing events: 100%|█████████▉| 385/386 [31:44<00:04,  4.84s/it]Your max_length is set to 512, but your input_length is only 416. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=208)
# Synthesizing events: 100%|██████████| 386/386 [31:48<00:00,  4.95s/it]
# ✅ Synthesized 386 multi-source event summaries.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🗑️ Previous JSON file deleted.
# ✅ JSON saved to Google Drive ➜ New News folder.

# %%
# 🚀 Auto-Port Fallback Web Server with ngrok (Colab-safe)

# STEP 1: Install pyngrok and set authtoken (only needed once per session)
# !pip install pyngrok --quiet
# !ngrok config add-authtoken 302IgATicSaOpwphBxpiVwONdMs_27qxv9BJm7XC62mXZs7s

# STEP 2: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# STEP 3: Start server on a free port from your Drive folder
import os
import http.server
import socketserver
import threading
from pyngrok import ngrok

# 📁 Path to the folder you want to serve (should contain index.html & JSON)
serve_dir = '/content/drive/MyDrive/New News'
os.chdir(serve_dir)

# 👇 Auto-try ports from 8000 to 8010
PORT = None
for try_port in range(8000, 8010):
    try:
        class ReusableTCPServer(socketserver.TCPServer):
            allow_reuse_address = True
        Handler = http.server.SimpleHTTPRequestHandler
        httpd = ReusableTCPServer(("0.0.0.0", try_port), Handler)
        PORT = try_port
        break
    except OSError:
        continue

# ❌ Failed to find a free port
if PORT is None:
    raise RuntimeError("❌ All ports from 8000–8009 are in use. Please restart the runtime.")

# ✅ Start ngrok tunnel
public_url = ngrok.connect(PORT)
print(f"\n✅ Server running on port {PORT}")
print(f"🌐 Public URL: {public_url}/index.html")

# ✅ Start server in background thread
threading.Thread(target=httpd.serve_forever).start()
print("🚀 Do not stop this cell while using the site.")
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# ✅ Server running on port 8001
# 🌐 Public URL: NgrokTunnel: "https://c8304829ed6c.ngrok-free.app" -> "http://localhost:8001"/index.html
# 🚀 Do not stop this cell while using the site.
